# %%
print("Hello")
# Out:
# Hello

# %%
# %sql
use database Dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from Employee
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Email</th></tr></thead><tbody><tr><td>John</td><td>JohnDevID@Test.com</td></tr><tr><td>Sam</td><td>SamDevID@Test.com</td></tr><tr><td>Smith</td><td>SmithDevID@Test.com</td></tr></tbody></table></div>

# %%
#convert table to a dataframe
df = sqlContext.table("Employee")

# %%
df.show()
# Out:
# +-----+-------------------+
# | Name|              Email|
# +-----+-------------------+
# | John| JohnDevID@Test.com|
# |  Sam|  SamDevID@Test.com|
# |Smith|SmithDevID@Test.com|
# +-----+-------------------+

# %%
#create a temporry view from the data frame
df.createOrReplaceTempView("testEmpView")

# %%
# %sql
select * from testEmpview
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Email</th></tr></thead><tbody><tr><td>John</td><td>JohnDevID@Test.com</td></tr><tr><td>Sam</td><td>SamDevID@Test.com</td></tr><tr><td>Smith</td><td>SmithDevID@Test.com</td></tr></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>dev</td><td>employee</td><td>false</td></tr><tr><td></td><td>testempview</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from testempview
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Email</th></tr></thead><tbody><tr><td>John</td><td>JohnDevID@Test.com</td></tr><tr><td>Sam</td><td>SamDevID@Test.com</td></tr><tr><td>Smith</td><td>SmithDevID@Test.com</td></tr></tbody></table></div>

# %%
# %sql
select Name,Email, REGEXP_REPLACE(REGEXP_REPLACE(Email,'DevID','ProdID'),'Test.com','Prod.com') AS NewEmail FROM testempview
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Email</th><th>NewEmail</th></tr></thead><tbody><tr><td>John</td><td>JohnDevID@Test.com</td><td>JohnProdID@Prod.com</td></tr><tr><td>Sam</td><td>SamDevID@Test.com</td><td>SamProdID@Prod.com</td></tr><tr><td>Smith</td><td>SmithDevID@Test.com</td><td>SmithProdID@Prod.com</td></tr></tbody></table></div>

# %%
#Convert the result back to a dataframe
Finaldf = spark.sql("select Name, REGEXP_REPLACE(Email,'DevID','ProdID') AS NewEmail FROM testempview")

# %%
Finaldf.show()
# Out:
# +-----+--------------------+
# | Name|            NewEmail|
# +-----+--------------------+
# | John| JohnProdID@Test.com|
# |  Sam|  SamProdID@Test.com|
# |Smith|SmithProdID@Test.com|
# +-----+--------------------+

# %%
# steps
# create a temperory view on top of Dataframe
# Use %sql magic command to convert the cell to SQL format
# Use sql regex replace function to replace the string with the the requried pattern
# Convert the result back to a dataframe
